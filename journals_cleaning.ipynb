# %% [markdown]
# # Cleaning Journals dataset

# %%
import pandas as pd

# %% [markdown]
# ### CheckinJournal.csv

# %%
cj_data = pd.read_csv("CheckinJournal.csv")

# %%
cj_data.head()
# Out:
#    participantId             timestamp  venueId   venueType
# 0            619  2022-03-01T05:35:00Z     1798         Pub
# 1             15  2022-03-01T05:50:00Z     1798         Pub
# 2             23  2022-03-01T05:55:00Z      894         Pub
# 3            699  2022-03-01T06:00:00Z     1798         Pub
# 4            876  2022-03-01T06:00:00Z     1804  Restaurant

# %%
cj_data.isna().sum()
# Out:
# participantId    0
# timestamp        0
# venueId          0
# venueType        0
# dtype: int64

# %%
cj_data.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2100630    False
# 2100631    False
# 2100632    False
# 2100633    False
# 2100634    False
# Length: 2100635, dtype: bool

# %%
print("Column datatypes: ")
print(cj_data.dtypes)
# Out:
# Column datatypes:
# participantId     int64
# timestamp        object
# venueId           int64
# venueType        object
# dtype: object

# %% [markdown]
# ### FinancialJournal.csv

# %%
fj_data = pd.read_csv("FinancialJournal.csv")

# %%
fj_data.head()
# Out:
#    participantId             timestamp   category       amount
# 0              0  2022-03-01T00:00:00Z       Wage  2472.507559
# 1              0  2022-03-01T00:00:00Z    Shelter  -554.988622
# 2              0  2022-03-01T00:00:00Z  Education   -38.005380
# 3              1  2022-03-01T00:00:00Z       Wage  2046.562206
# 4              1  2022-03-01T00:00:00Z    Shelter  -554.988622

# %%
fj_data.isna().sum()
# Out:
# participantId    0
# timestamp        0
# category         0
# amount           0
# dtype: int64

# %%
fj_data.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1856325    False
# 1856326    False
# 1856327    False
# 1856328    False
# 1856329    False
# Length: 1856330, dtype: bool

# %%
print(fj_data.dtypes)
# Out:
# participantId      int64
# timestamp         object
# category          object
# amount           float64
# dtype: object

# %% [markdown]
# ### SocialNetwork.csv

# %%
s_data = pd.read_csv("SocialNetwork.csv")

# %%
s_data.head()
# Out:
#               timestamp  participantIdFrom  participantIdTo
# 0  2022-03-01T00:00:00Z                173              180
# 1  2022-03-01T00:00:00Z                178              183
# 2  2022-03-01T00:00:00Z                178              185
# 3  2022-03-01T00:00:00Z                180              173
# 4  2022-03-01T00:00:00Z                183              178

# %%
s_data.isna().sum()
# Out:
# timestamp            0
# participantIdFrom    0
# participantIdTo      0
# dtype: int64

# %%
s_data.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 7482483    False
# 7482484    False
# 7482485    False
# 7482486    False
# 7482487    False
# Length: 7482488, dtype: bool

# %% [markdown]
# ### TravelJournal.csv

# %%
t_data = pd.read_csv("TravelJournal.csv")

# %%
t_data.head()
# Out:
#    participantId       travelStartTime  travelStartLocationId  \
# 0             23  2022-03-01T05:20:00Z                  532.0
# 1            876  2022-03-01T05:50:00Z                    NaN
# 2            902  2022-03-01T06:05:00Z                    NaN
# 3            919  2022-03-01T06:00:00Z                    NaN
# 4            154  2022-03-01T05:55:00Z                    NaN
#
#           travelEndTime  travelEndLocationId                        purpose  \
# 0  2022-03-01T05:55:00Z                  894  Recreation (Social Gathering)
# 1  2022-03-01T06:00:00Z                 1804                         Eating
# 2  2022-03-01T06:10:00Z                 1801                         Eating
# 3  2022-03-01T06:10:00Z                 1802                         Eating
# 4  2022-03-01T06:10:00Z                  446                         Eating
#
#             checkInTime          checkOutTime  startingBalance  endingBalance
# ...

# %%
t_data.isna().sum()
# Out:
# participantId               0
# travelStartTime             0
# travelStartLocationId    1043
# travelEndTime               0
# travelEndLocationId         0
# purpose                     0
# checkInTime                 0
# checkOutTime                0
# startingBalance             0
# endingBalance               0
# dtype: int64

# %%
t_data['travelStartLocationId'].fillna(0, inplace=True)

# %%
t_data.isna().sum().sum()
# Out:
# 0

# %%
t_data.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2099651    False
# 2099652    False
# 2099653    False
# 2099654    False
# 2099655    False
# Length: 2099656, dtype: bool

# %%
# # new column added total travel duration in minutes

# # Convert 'travelStartTime' and 'travelEndTime' columns to datetime
# t_data['travelStartTime'] = pd.to_datetime(t_data['travelStartTime'])
# t_data['travelEndTime'] = pd.to_datetime(t_data['travelEndTime'])

# # Calculate travel duration in seconds
# t_data['travelDuration'] = (t_data['travelEndTime'] - t_data['travelStartTime']).dt.total_seconds()

# # Convert travel duration to hours and assign to 'total_travel_duration' column
# t_data['travelDurationMinutes'] =t_data['travelDuration'] / 60

# %%
t_data
# Out:
#          participantId           travelStartTime  travelStartLocationId  \
# 0                   23 2022-03-01 05:20:00+00:00                  532.0
# 1                  876 2022-03-01 05:50:00+00:00                    0.0
# 2                  902 2022-03-01 06:05:00+00:00                    0.0
# 3                  919 2022-03-01 06:00:00+00:00                    0.0
# 4                  154 2022-03-01 05:55:00+00:00                    0.0
# ...                ...                       ...                    ...
# 2099651            376 2023-05-24 21:15:00+00:00                 1449.0
# 2099652            782 2023-05-24 21:30:00+00:00                 1139.0
# 2099653             39 2023-05-24 23:30:00+00:00                  188.0
# 2099654             28 2023-05-24 21:30:00+00:00                 1254.0
# 2099655            370 2023-05-24 21:55:00+00:00                  556.0
#
#                     travelEndTime  travelEndLocationId  \
# ...

# %%
# # total spending = starting balance - ending balance
# t_data['totalSpending'] = t_data['startingBalance'] - t_data['endingBalance']

# %%
t_data
# Out:
#          participantId           travelStartTime  travelStartLocationId  \
# 0                   23 2022-03-01 05:20:00+00:00                  532.0
# 1                  876 2022-03-01 05:50:00+00:00                    0.0
# 2                  902 2022-03-01 06:05:00+00:00                    0.0
# 3                  919 2022-03-01 06:00:00+00:00                    0.0
# 4                  154 2022-03-01 05:55:00+00:00                    0.0
# ...                ...                       ...                    ...
# 2099651            376 2023-05-24 21:15:00+00:00                 1449.0
# 2099652            782 2023-05-24 21:30:00+00:00                 1139.0
# 2099653             39 2023-05-24 23:30:00+00:00                  188.0
# 2099654             28 2023-05-24 21:30:00+00:00                 1254.0
# 2099655            370 2023-05-24 21:55:00+00:00                  556.0
#
#                     travelEndTime  travelEndLocationId  \
# ...

# %%
try:
    t_data.to_csv('/Users/harshithabenakanahallinagaraj/Desktop/VAST-Challenge-2022/Datasets/Journals/cleaned_journals_data/travelJournal.csv', index=False)
    print("File saved successfully.")
except Exception as e:
    print("An error occurred while saving the file:", str(e))
# Out:
# File saved successfully.

# %% [markdown]
# #### Data is cleaned
