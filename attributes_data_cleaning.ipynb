# %% [markdown]
# # *Cleaning Attributes Dataset*

# %%
import pandas as pd

# %% [markdown]
# ### Apartments.csv

# %%
apartments_data = pd.read_csv("Apartments.csv")

# %%
apartments_data.head()
# Out:
#    apartmentId  rentalCost  maxOccupancy   numberOfRooms  \
# 0            1      768.16              2              4
# 1            2     1014.55              2              1
# 2            3     1057.39              4              3
# 3            4     1259.10              4              3
# 4            5      411.50              1              4
#
#                                         location  buildingId
# 0   POINT (1077.6979444315298 648.4427163702453)         340
# 1  POINT (-185.9292838076562 1520.3270983045118)         752
# 2   POINT (2123.0141855392585 5126.753457243003)         639
# 3   POINT (2103.6301776944765 4266.932930123476)         397
# 4   POINT (7.0589743819342985 79.96163671849988)         628

# %%
apartments_data.isna().sum()
# Out:
# apartmentId      0
# rentalCost       0
# maxOccupancy     0
# numberOfRooms    0
# location         0
# buildingId       0
# dtype: int64

# %%
apartments_columns= list(apartments_data.columns)
apartments_columns
# Out:
# ['apartmentId',
#  'rentalCost',
#  'maxOccupancy ',
#  'numberOfRooms',
#  'location',
#  'buildingId']

# %%
print("Missing values distribution: ")
print((apartments_data.isnull().mean() * 100).round(2))
print("")
# Out:
# Missing values distribution:
# apartmentId      0.0
# rentalCost       0.0
# maxOccupancy     0.0
# numberOfRooms    0.0
# location         0.0
# buildingId       0.0
# dtype: float64

# %%
print("Column datatypes: ")
print(apartments_data.dtypes)
# Out:
# Column datatypes:
# apartmentId        int64
# rentalCost       float64
# maxOccupancy       int64
# numberOfRooms      int64
# location          object
# buildingId         int64
# dtype: object

# %%
apartments_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   apartmentId    1517 non-null   int64
#  1   rentalCost     1517 non-null   float64
#  2   maxOccupancy   1517 non-null   int64
#  3   numberOfRooms  1517 non-null   int64
#  4   location       1517 non-null   object
#  5   buildingId     1517 non-null   int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 71.2+ KB

# %%
apartments_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1512    False
# 1513    False
# 1514    False
# 1515    False
# 1516    False
# Length: 1517, dtype: bool

# %%
# splitting location into latitude and longitude
# apartments_data['latitude'] = apartments_data['location'].apply(lambda x: float(x.split(' ')[1][1:]))
# apartments_data['longitude'] = apartments_data['location'].apply(lambda x: float(x.split(' ')[2][:-1]))

# %%
# drop location column
#apartments_data = apartments_data.drop('location', axis=1)
apartments_data
# Out:
#       apartmentId  rentalCost  maxOccupancy   numberOfRooms  buildingId  \
# 0               1      768.16              2              4         340
# 1               2     1014.55              2              1         752
# 2               3     1057.39              4              3         639
# 3               4     1259.10              4              3         397
# 4               5      411.50              1              4         628
# ...           ...         ...            ...            ...         ...
# 1512         1729      703.80              2              4         182
# 1513         1730     1104.62              4              2         613
# 1514         1731      890.69              4              1         513
# 1515         1732      703.80              2              3         182
# 1516         1733      607.99              2              3         913
#
#          latitude    longitude
# 0     1077.697944   648.442716
# 1     -185.929284  1520.327098
# ...

# %%
apartments_data.to_csv('apartments_data.csv', index=False)

# %% [markdown]
# ### Buildings.csv

# %%
buildings_df = pd.read_csv("Buildings.csv")

# %%
buildings_df.head()
# Out:
#    buildingId                                           location buildingType  \
# 0           1  POLYGON ((350.0638997002585 4595.665606173783,...   Commercial
# 1           2  POLYGON ((-1926.972613718425 2725.610686806701...   Residental
# 2           3  POLYGON ((685.6846002015491 1552.131491805318,...   Commercial
# 3           4  POLYGON ((-976.7845160060303 4542.38209636188,...   Commercial
# 4           5  POLYGON ((1259.3061988755617 3572.726728111263...   Residental
#
#    maxOccupancy                  units
# 0           NaN                    NaN
# 1          12.0  [481,498,534,652,818]
# 2           NaN                  [382]
# 3           NaN                    NaN
# 4           2.0                  [231]

# %%
buildings_data.isna().sum()
# Out:
# buildingId        0
# location          0
# buildingType      0
# maxOccupancy    539
# units           369
# dtype: int64

# %%
# Fill NaN values in "maxOccupancy" and "units" with 0
buildings_df["maxOccupancy"].fillna(1, inplace=True)
buildings_df["units"].fillna(1, inplace=True)

# %%
buildings_df.isna().sum().sum()
# Out:
# 0

# %%
buildings_cols= list(buildings_df.columns)
buildings_cols
print("Missing values distribution: ")
print((buildings_df.isnull().mean() * 100).round(2))
print("")
# Out:
# Missing values distribution:
# buildingId      0.0
# buildingType    0.0
# maxOccupancy    0.0
# units           0.0
# latitude        0.0
# longitude       0.0
# dtype: float64

# %%
print("Column datatypes: ")
print(buildings_df.dtypes)
# Out:
# Column datatypes:
# buildingId        int64
# buildingType     object
# maxOccupancy    float64
# units            object
# latitude        float64
# longitude       float64
# dtype: object

# %%
buildings_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# Length: 1042, dtype: bool

# %%
buildings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   buildingId    1042 non-null   int64
#  1   buildingType  1042 non-null   object
#  2   maxOccupancy  1042 non-null   float64
#  3   units         1042 non-null   object
#  4   latitude      1042 non-null   float64
#  5   longitude     1042 non-null   float64
#  6   totalUnits    1042 non-null   int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 57.1+ KB

# %%
# # splitting location into latitude and longitude
# from shapely.geometry import Polygon
# lat_lng_pairs = []
# for index, row in buildings_df.iterrows():
#     location = row["location"]
#     coordinates = location.replace("POLYGON ((", "").replace("))", "").replace("(", "").replace(")", "").split(", ")
#     lat_lng_pairs_row = []
#     for coordinate in coordinates:
#         lat, lng = map(float, coordinate.strip().split(" "))
#         lat_lng_pairs_row.append((lat, lng))
#     lat_lng_pairs.append(lat_lng_pairs_row)

# buildings_df["latitude"] = [pair[0][0] if pair else None for pair in lat_lng_pairs]
# buildings_df["longitude"] = [pair[0][1] if pair else None for pair in lat_lng_pairs]

# %%
# # drop location column
# buildings_df = buildings_df.drop('location', axis=1)

# %%
buildings_df
# Out:
#       buildingId buildingType  maxOccupancy                  units  \
# 0              1   Commercial           1.0                      1
# 1              2   Residental          12.0  [481,498,534,652,818]
# 2              3   Commercial           1.0                  [382]
# 3              4   Commercial           1.0                      1
# 4              5   Residental           2.0                  [231]
# ...          ...          ...           ...                    ...
# 1037        1038   Residental           8.0              [118,287]
# 1038        1039   Residental           2.0                  [365]
# 1039        1040   Residental           5.0       [1406,1564,1569]
# 1040        1041   Commercial           1.0                 [1737]
# 1041        1042   Commercial           1.0                      1
#
#          latitude    longitude  totalUnits
# 0      350.063900  4595.665606           1
# 1    -1926.972614  2725.610687           5
# ...

# %%
# import ast

# # Convert "units" into total units count
# buildings_df["totalUnits"] = buildings_df["units"].apply(lambda x: len(ast.literal_eval(x)) if isinstance(x, str) else 1)

# %%
buildings_df.to_csv('buildings_data.csv', index=False)

# %% [markdown]
# ### Employers.csv

# %%
employers_df = pd.read_csv("Employers.csv")

# %%
employers_df.head()
# Out:
#    employerId                                       location  buildingId
# 0         379  POINT (-1849.997168394888 1744.6010147106394)         823
# 1         380    POINT (41.51783767879146 418.7264799744545)         154
# 2         381   POINT (877.2786575380362 1358.5441805909259)         279
# 3         382   POINT (670.3987400004884 1584.4743462106067)           3
# 4         383   POINT (829.9556783260775 2163.4803049897623)         146

# %%
employers_df.isna().sum()
# Out:
# employerId    0
# location      0
# buildingId    0
# dtype: int64

# %%
print("Missing values distribution: ")
print((employers_df.isnull().mean() * 100).round(2))
print("")
# Out:
# Missing values distribution:
# employerId    0.0
# location      0.0
# buildingId    0.0
# dtype: float64

# %%
print("Column datatypes: ")
print(employers_df.dtypes)
# Out:
# Column datatypes:
# employerId     int64
# location      object
# buildingId     int64
# dtype: object

# %%
employers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   employerId  253 non-null    int64
#  1   location    253 non-null    object
#  2   buildingId  253 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 6.1+ KB

# %%
employers_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 248    False
# 249    False
# 250    False
# 251    False
# 252    False
# Length: 253, dtype: bool

# %%
# # splitting location into latitude and longitude
# employers_df['latitude'] = employers_df['location'].apply(lambda x: float(x.split(' ')[1][1:]))
# employers_df['longitude'] = employers_df['location'].apply(lambda x: float(x.split(' ')[2][:-1]))

# %%
# drop location column
# employers_df = employers_df.drop('location', axis=1)
employers_df
# Out:
#      employerId  buildingId     latitude    longitude
# 0           379         823 -1849.997168  1744.601015
# 1           380         154    41.517838   418.726480
# 2           381         279   877.278658  1358.544181
# 3           382           3   670.398740  1584.474346
# 4           383         146   829.955678  2163.480305
# ..          ...         ...          ...          ...
# 248        1793         738 -3313.211913  6185.833728
# 249        1794         802 -3786.373075  4999.485452
# 250        1795         953 -3267.606055  6452.567059
# 251        1796        1011 -3725.261225  6345.551342
# 252        1797         949 -3759.480918  5179.602736
#
# [253 rows x 4 columns]

# %%
employers_df.to_csv('employers_data.csv', index=False)

# %% [markdown]
# ### Jobs.csv

# %%
jobs_df = pd.read_csv("Jobs.csv")

# %%
jobs_df.head()
# Out:
#    jobId  employerId  hourlyRate   startTime     endTime  \
# 0      0         379   10.000000  7:46:00 AM  3:46:00 PM
# 1      1         379   22.217633  7:31:00 AM  3:31:00 PM
# 2      2         380   10.000000  8:00:00 AM  4:00:00 PM
# 3      3         380   15.312071  7:39:00 AM  3:39:00 PM
# 4      4         381   21.355409  7:53:00 AM  3:53:00 PM
#
#                                    daysToWork educationRequirement
# 0  [Monday,Tuesday,Wednesday,Thursday,Friday]  HighSchoolOrCollege
# 1  [Monday,Tuesday,Wednesday,Thursday,Friday]            Bachelors
# 2  [Monday,Tuesday,Wednesday,Thursday,Friday]            Bachelors
# 3  [Monday,Tuesday,Wednesday,Thursday,Friday]            Bachelors
# 4  [Monday,Tuesday,Wednesday,Thursday,Friday]  HighSchoolOrCollege

# %%
jobs_df.isna().sum()
# Out:
# jobId                   0
# employerId              0
# hourlyRate              0
# startTime               0
# endTime                 0
# daysToWork              0
# educationRequirement    0
# dtype: int64

# %%
jobs_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1323    False
# 1324    False
# 1325    False
# 1326    False
# 1327    False
# Length: 1328, dtype: bool

# %%
print("Missing values distribution: ")
print((jobs_df.isnull().mean() * 100).round(2))
print("")
# Out:
# Missing values distribution:
# jobId                   0.0
# employerId              0.0
# hourlyRate              0.0
# startTime               0.0
# endTime                 0.0
# daysToWork              0.0
# educationRequirement    0.0
# dtype: float64

# %%
print("Column datatypes: ")
print(jobs_df.dtypes)
# Out:
# Column datatypes:
# jobId                     int64
# employerId                int64
# hourlyRate              float64
# startTime                object
# endTime                  object
# daysToWork               object
# educationRequirement     object
# dtype: object

# %%
# # new column that calculates duration of work in hours

# jobs_df['startTime'] = pd.to_datetime(jobs_df['startTime'])
# jobs_df['endTime'] = pd.to_datetime(jobs_df['endTime'])

# jobs_df['totalTime'] = (jobs_df['endTime'] - jobs_df['startTime']).dt.total_seconds() / 3600

# %%
jobs_df
# Out:
#       jobId  employerId  hourlyRate           startTime             endTime  \
# 0         0         379   10.000000 2023-07-02 07:46:00 2023-07-02 15:46:00
# 1         1         379   22.217633 2023-07-02 07:31:00 2023-07-02 15:31:00
# 2         2         380   10.000000 2023-07-02 08:00:00 2023-07-02 16:00:00
# 3         3         380   15.312071 2023-07-02 07:39:00 2023-07-02 15:39:00
# 4         4         381   21.355409 2023-07-02 07:53:00 2023-07-02 15:53:00
# ...     ...         ...         ...                 ...                 ...
# 1323   1323        1796   37.166553 2023-07-02 07:29:00 2023-07-02 15:29:00
# 1324   1324        1796   23.815211 2023-07-02 08:14:00 2023-07-02 16:14:00
# 1325   1325        1797   13.117569 2023-07-02 07:37:00 2023-07-02 15:37:00
# 1326   1326        1797   10.000000 2023-07-02 07:31:00 2023-07-02 15:31:00
# 1327   1327        1797   11.932836 2023-07-02 08:19:00 2023-07-02 16:19:00
#
# ...

# %%
# # adding a new column number of days in total
# # Custom mapping for weekday names
# weekday_mapping = {
#     'Monday': 1,
#     'Tuesday': 2,
#     'Wednesday': 3,
#     'Thursday': 4,
#     'Friday': 5,
#     'Saturday' : 6,
#     'Sunday' : 7,
    
# }

# # Convert the daysToWork column into the total number of days
# jobs_df['totalDays'] = jobs_df['daysToWork'].apply(lambda x: len(eval(x, weekday_mapping)) if isinstance(x, str) else 0)

# %%
jobs_df.to_csv('jobs_data.csv', index=False)

# %% [markdown]
# ### Participants.csv

# %%
p_df = pd.read_csv("Participants.csv")

# %%
p_df.head()
# Out:
#    participantId  householdSize  haveKids  age       educationLevel  \
# 0              0              3      True   36  HighSchoolOrCollege
# 1              1              3      True   25  HighSchoolOrCollege
# 2              2              3      True   35  HighSchoolOrCollege
# 3              3              3      True   21  HighSchoolOrCollege
# 4              4              3      True   43            Bachelors
#
#   interestGroup  joviality
# 0             H   0.001627
# 1             B   0.328087
# 2             A   0.393470
# 3             I   0.138063
# 4             H   0.857397

# %%
p_df.isna().sum()
# Out:
# participantId     0
# householdSize     0
# haveKids          0
# age               0
# educationLevel    0
# interestGroup     0
# joviality         0
# dtype: int64

# %%
p_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1006    False
# 1007    False
# 1008    False
# 1009    False
# 1010    False
# Length: 1011, dtype: bool

# %%
print("Column datatypes: ")
print(p_df.dtypes)
# Out:
# Column datatypes:
# participantId       int64
# householdSize       int64
# haveKids             bool
# age                 int64
# educationLevel     object
# interestGroup      object
# joviality         float64
# dtype: object

# %%
p_df.to_csv('participants_data.csv', index=False)

# %% [markdown]
# ### Pubs.csv

# %%
pubs_df = pd.read_csv("Pubs.csv")

# %%
pubs_df
# Out:
#     pubId  hourlyCost  maxOccupancy  \
# 0     442    8.281103            64
# 1     443    6.417435            64
# 2     444   12.581806            84
# 3     892   11.642905            96
# 4     893   14.840473            79
# 5     894   12.311210            72
# 6    1342   14.140037            77
# 7    1343   10.524972            67
# 8    1344   10.415293            60
# 9    1798   11.545351            64
# 10   1799    7.487082            73
# 11   1800   10.206845            62
#
#                                          location  buildingId
# 0     POINT (964.4380231713202 3991.603473784208)         556
# 1     POINT (1809.880173357865 4339.172426035451)          29
# 2     POINT (770.4279044387976 932.5852003214752)        1012
# 3   POINT (-1524.9573211662105 3815.271490114369)         502
# 4   POINT (-1608.766411449925 3886.4924784954583)         164
# 5   POINT (-1702.5378155541193 3865.477090848479)         238
# ...

# %%
pubs_df.isna().sum()
# Out:
# pubId           0
# hourlyCost      0
# maxOccupancy    0
# location        0
# buildingId      0
# dtype: int64

# %%
pubs_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
# # splitting location into latitude and longitude
# pubs_df['latitude'] = pubs_df['location'].apply(lambda x: float(x.split(' ')[1][1:]))
# pubs_df['longitude'] = pubs_df['location'].apply(lambda x: float(x.split(' ')[2][:-1]))

# # drop location column
# pubs_df = pubs_df.drop('location', axis=1)

# %%
pubs_df
# Out:
#     pubId  hourlyCost  maxOccupancy  buildingId     latitude    longitude
# 0     442    8.281103            64         556   964.438023  3991.603474
# 1     443    6.417435            64          29  1809.880173  4339.172426
# 2     444   12.581806            84        1012   770.427904   932.585200
# 3     892   11.642905            96         502 -1524.957321  3815.271490
# 4     893   14.840473            79         164 -1608.766411  3886.492478
# 5     894   12.311210            72         238 -1702.537816  3865.477091
# 6    1342   14.140037            77         429  -260.457471  5026.150804
# 7    1343   10.524972            67         489  -501.426761  3551.572639
# 8    1344   10.415293            60         585  -225.920987  3878.053698
# 9    1798   11.545351            64         953 -3209.738139  6487.657688
# 10   1799    7.487082            73         234 -3903.194076  5967.836984
# 11   1800   10.206845            62         627 -3796.119851  6367.922073

# %%
pubs_df.to_csv('pubs_data.csv', index=False)

# %% [markdown]
# ### Restaurants.csv

# %%
r_df = pd.read_csv("Restaurants.csv")

# %%
r_df
# Out:
#     restaurantId  foodCost  maxOccupancy   \
# 0            445      5.15             71
# 1            446      4.17             82
# 2            447      5.87            119
# 3            448      4.07             98
# 4            449      5.11             53
# 5            895      4.44            103
# 6            896      5.86            107
# 7            897      5.76            104
# 8            898      4.22            115
# 9            899      5.65             85
# 10          1345      4.70             72
# 11          1346      5.85             74
# 12          1347      4.41             87
# 13          1348      4.23             57
# 14          1349      4.77            104
# 15          1801      5.51             64
# 16          1802      5.08             72
# 17          1803      4.35             94
# 18          1804      5.92             48
# 19          1805      5.59             85
#
#                                           location  buildingId
# ...

# %%
r_df.isna().sum()
# Out:
# restaurantId     0
# foodCost         0
# maxOccupancy     0
# location         0
# buildingId       0
# dtype: int64

# %%
r_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
# # # splitting location into latitude and longitude
# r_df['latitude'] = r_df['location'].apply(lambda x: float(x.split(' ')[1][1:]))
# r_df['longitude'] = r_df['location'].apply(lambda x: float(x.split(' ')[2][:-1]))

# # # drop location column
# r_df= r_df.drop('location', axis=1)

# %%
r_df
# Out:
#     restaurantId  foodCost  maxOccupancy   buildingId     latitude  \
# 0            445      5.15             71         304   631.513072
# 1            446      4.17             82         308   413.840001
# 2            447      5.87            119          58   497.996794
# 3            448      4.07             98         964   698.241116
# 4            449      5.11             53         181  1407.710770
# 5            895      4.44            103         164 -1623.074059
# 6            896      5.86            107         619 -2126.172394
# 7            897      5.76            104         875 -1989.635264
# 8            898      4.22            115         917 -1771.452217
# 9            899      5.65             85          86  -820.929028
# 10          1345      4.70             72         991 -1176.801330
# 11          1346      5.85             74          27 -3529.558387
# 12          1347      4.41             87         679 -1221.405110
# ...

# %%
r_df.to_csv('restaurants_data.csv', index=False)

# %% [markdown]
# ### Schools.csv

# %%
s_df = pd.read_csv("Schools.csv")

# %%
s_df
# Out:
#    schoolId  monthlyCost  maxEnrollment  \
# 0         0    12.812445            242
# 1       450    91.143514            418
# 2       900    38.005380            394
# 3      1350    73.197852            384
#
#                                          location  buildingId
# 0   POINT (-376.7505037068263 1607.9843212558562)         662
# 1   POINT (-2597.447677094323 3194.1547530883445)         943
# 2  POINT (-2539.1584040534744 6556.0323181733565)         262
# 3    POINT (-4701.462928834322 5141.762936081409)         123

# %%
s_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
# #  splitting location into latitude and longitude
# s_df['latitude'] =s_df['location'].apply(lambda x: float(x.split(' ')[1][1:]))
# s_df['longitude'] = s_df['location'].apply(lambda x: float(x.split(' ')[2][:-1]))

# #  drop location column
# s_df= s_df.drop('location', axis=1)

# %%
s_df
# Out:
#    schoolId  monthlyCost  maxEnrollment  buildingId     latitude    longitude
# 0         0    12.812445            242         662  -376.750504  1607.984321
# 1       450    91.143514            418         943 -2597.447677  3194.154753
# 2       900    38.005380            394         262 -2539.158404  6556.032318
# 3      1350    73.197852            384         123 -4701.462929  5141.762936

# %%
s_df.to_csv('schools_data.csv', index=False)

# %% [markdown]
# #### Data is cleaned
